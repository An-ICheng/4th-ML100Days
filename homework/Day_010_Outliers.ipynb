# %% [markdown]
# # 範例 : (Kaggle)房價預測
# ***
# - 以下用房價預測資料, 觀察去除離群值的影響

# %% [markdown]
# # [教學目標]
# - 以下用房價預測資料, 觀察去除離群值的影響

# %% [markdown]
# # [範例重點]
# - 觀察原始數值的散佈圖, 以及線性迴歸分數 (In[5], Out[5])
# - 觀察將極端值以上下限值取代, 對於分布與迴歸分數的影響 (In[6], Out[6])
# - 觀察將極端值資料直接刪除, 對於分布與迴歸分數的影響 (In[7], Out[7])

# %% [markdown]
# ### About log1p():
# 1.log1p( ) 的使用就像是一个数据压缩到了一个区间，与数据的标准类似。其逆运算就是expm1的函数，即lop1p()就用expm1()來轉換回去
# -reference
# https://blog.csdn.net/u012193416/article/details/83211016
# https://medium.com/@skywalker0803r/kaggle%E6%AF%94%E8%B3%BD%E9%A1%8C%E7%9B%AE%E4%BB%8B%E7%B4%B9-%E6%88%BF%E5%83%B9%E9%A0%90%E6%B8%AC-1-42adc4e12e1b
#
# 2.log1p(x) = log(x+1) 即ln(x+1)。參考資料https://www.itread01.com/content/1545014888.html

# %%
# 做完特徵工程前的所有準備 (與前範例相同)
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

data_path = '/Users/anncheng/Documents/GitHub/4th-ML100Days/data/'
df_train = pd.read_csv(data_path + 'house_train.csv.gz') # Read a comma-separated values (csv) file into DataFrame.

# df_train['SalePrice']
train_Y = np.log1p(df_train['SalePrice'])
# train_Y
df = df_train.drop(['Id', 'SalePrice'] , axis=1) # axis=1是指從column刪除一整行，也就是直的刪除資料
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 1         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
# 2         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 3         Lvl    AllPub    Corner  ...           0        0    NaN   NaN
# 4         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
#只取 int64, float64 兩種數值型欄位, 存於 num_features 中
num_features = []
for dtype, feature in zip(df.dtypes, df.columns):
    if dtype == 'float64' or dtype == 'int64':
        num_features.append(feature)
print(f'{len(num_features)} Numeric Features : {num_features}\n')
# Out:
# 36 Numeric Features : ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %%
# 上一個cell已完成削減文字型欄位, df[num_features]執行後新的df裡只剩num_features指進去得數值型欄位,欄位數量從79變只剩36個。
df = df[num_features]
df = df.fillna(-1) # na處填上-1
MMEncoder = MinMaxScaler() #轉換數值使其default介於0~1
df.head()
df
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %%
# 顯示 GrLivArea 與目標值的散佈圖
import seaborn as sns
import matplotlib.pyplot as plt
sns.regplot(x = df['GrLivArea'], y=train_Y)
plt.show()

# 做線性迴歸, 觀察分數
train_X = MMEncoder.fit_transform(df) # fit_transform見之前筆記https://github.com/An-ICheng/4th-ML100Days/blob/master/homework/Day_006_column_data_type.ipynb
# train_X
estimator = LinearRegression() 
# LinearRegression()
# estimator

# 初步判斷estimator是填演算法與回歸方法的地方，如KNeighborsClassifier()、LinearRegression()、LogisticRegression()。
# reference-1:https://blog.csdn.net/weixin_38536057/article/details/78702564
# reference-2:https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html
# 有estimator這個放演算法的地方是因為交叉驗證會用到你自己指定的演算法，交叉驗證步驟如：分成幾堆資料>用演算法去產生model，再用model預測結果並與真實結果比對以知道此model正確率(即score)等高不高
cross_val_score(estimator, train_X, train_Y, cv=5).mean() # mean是把cv算5次產生的5個score取mean。
# Out:
# 0.84660496795894

# %%
# 將 GrLivArea 限制在 800 到 2500 以內, 調整離群值
df['GrLivArea'] = df['GrLivArea'].clip(800, 2500) # clip(800,2500)是<800的全部換成800，>2500的全部換成2500
# df['GrLivArea'].max()
sns.regplot(x = df['GrLivArea'], y=train_Y)
plt.show()

# 做線性迴歸, 觀察分數
train_X = MMEncoder.fit_transform(df)
estimator = LinearRegression()
cross_val_score(estimator, train_X, train_Y, cv=5).mean()
# Out:
# 0.8590286613713278

# %%
# 將 GrLivArea 限制在 800 到 2500 以內, 捨棄離群值
# (df['GrLivArea']>800) & (df['GrLivArea']< 250) 執行結果為True、False
keep_indexs = (df['GrLivArea']> 800) & (df['GrLivArea']< 2500) # <800的都捨棄，>2500得也都捨棄
# df[keep_indexs]
df = df[keep_indexs] # 執行結果把df中是True的row留著，False的row捨棄，所以新df的row數量會變少
train_Y = train_Y[keep_indexs] # 執行結果把train_Y中對應到keep_indexs是True的row的train_Y的值留著，False的row的train_Y的值捨棄
sns.regplot(x = df['GrLivArea'], y=train_Y) # 因為上面整個df已經經過True的row留著，False的row捨棄的步驟，所以已產生新的df，所以df['GrLivArea']也只剩下True的row
plt.show()

# 做線性迴歸, 觀察分數
train_X = MMEncoder.fit_transform(df)
estimator = LinearRegression()
cross_val_score(estimator, train_X, train_Y, cv=5).mean() #
# Out:
# 0.8765809666638813

# %% [markdown]
# # 作業1
# * 試著限制 '1樓地板面積(平方英尺)' (1stFlrSF) 欄位的上下限, 看看能否再進一步提高分數?
#
# # 作業2
# * 續前題, 去除離群值有兩類方式 :  捨棄離群值(刪除離群的資料) 以及調整離群值,
# 請試著用同樣的上下限, 改為 '捨棄離群值' 的方法, 看看結果會變好還是變差? 並試著解釋原因。
